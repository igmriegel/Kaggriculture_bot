# %%
# Install our uploaded wheel package using wildcard
# !pip install /kaggle/input/kaggriculture-bot-code/*.whl

# %%
# Install stable-baselines3 and cmaes for RL and optimization
# !pip install stable-baselines3 cmaes

# %%
# Run RL (PPO) training
# !python /kaggle/input/kaggriculture-bot-code/kaggle_runner.py --mode rl --steps 50000 --output /kaggle/working/best_ppo_model

# %%
# Run Optuna CMA-ES optimization
# !python /kaggle/input/kaggriculture-bot-code/kaggle_runner.py --mode optuna --trials 200 --output /kaggle/working/best_optuna_params
